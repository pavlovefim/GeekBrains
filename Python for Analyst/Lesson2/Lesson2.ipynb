# %% [markdown]
# 1 задача
#  - Скачать данные по ссылке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information
#  - Считать данные с помощью pandas
#  - Вывести на экран первые 5 строк
#  - Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('//Users/efim/Desktop/GeekBrains/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail(7)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# ...

# %% [markdown]
# 2 задача
#  - Проведите первичный анализ данных
#  - Изучите типы данных
#  - Найдите количество пропущенных ячеек в данных [не найденно]
#  - Посчитайте основные статистики по всем признакам и поизучайте их
#  - Пишите выводы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include=['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# 3 задача
# Ответьте на несколько вопросов
# 3.1 В каком диапазоне изменяются стоимости недвижимости? [- от 75 тыс. до 7.7 млн.]
# 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам? [0.14]
# 3.3 Как много домов с разными этажами в данных?
# 3.4 Насколько хорошие состояния у домов в данных?
# 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных? [-первый - в 1900, последний - в 2015]

# %%
df['price'].describe() # цена от 75 тыс. до 7.7 млн.
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
df['sqft_living'].mean()/df['sqft_lot'].mean()
# Out:
# 0.1376781757959227

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
df['floors'].value_counts(normalize=True)
# Out:
# 1.0    0.494147
# 2.0    0.381298
# 1.5    0.088373
# 3.0    0.028363
# 2.5    0.007449
# 3.5    0.000370
# Name: floors, dtype: float64

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
df['yr_built'].describe() # первый построили в 1900, последний - в 2015.
# Out:
# count    21613.000000
# mean      1971.005136
# std         29.373411
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %% [markdown]
# 4 задача.
# Ответьте на несколько вопросов:
# 4.1 Сколько в среднем стоят дома, у которых 2 спальни? [401 373]
# 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000? [20 443]
# 4.3 Как много домов коснулся ремонт? [914]
# 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4? [1 488 885]

# %%
df[df['bedrooms']==2]['price'].mean()
# Out:
# 401372.681884058

# %%
df[df['price']>600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %%
df[df['yr_renovated']==0]['yr_renovated'].value_counts()
# Out:
# 0    20699
# Name: yr_renovated, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df[(df['yr_renovated'] != 0)].shape[0]
# Out:
# 914

# %%
df[df['grade']>10]['price'].mean() - df[df['grade']<4]['price'].mean()
# Out:
# 1488885.1175298805

# %% [markdown]
# 5 задача.
# Ответьте на несколько вопросов:
# 5.1 Выберите дом клиенту:
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента? [41]
# 5.2 Выберите дом клиенту:
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома? - [415 000 : 3 000 000]
# 5.3 Выберите дом клиенту:
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем? [3]

# %%
df1 = df[(df['waterfront']!=0) & (df['bathrooms']>=3) & (df['sqft_basement']!=0)]
df1
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1261   7636800041  20140625T000000   995000.0         3       4.50
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1361   1925069082  20150511T000000  2200000.0         5       4.25
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 3934   1269200229  20140723T000000  1379900.0         3       3.25
# 5760    623059016  20140717T000000  1100000.0         4       3.25
# 6233   2024069008  20140619T000000  2200000.0         5       4.75
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# ...

# %%
df2 = df[((df['waterfront']!=0) | (df['view']!=0)) & (df['condition']==df['condition'].max()) & (df['yr_built']>=1980)]
df2
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 858     623069068  20140627T000000   425000.0         3       1.00
# 3821   5452301810  20140905T000000  1575000.0         5       3.75
# 6045   4045100190  20141027T000000  2196000.0         4       3.25
# 8136   2597450620  20141009T000000  1511250.0         3       2.50
# 8791   5067400032  20141205T000000   550000.0         3       2.50
# 11257  3761100045  20140618T000000  3000000.0         4       4.25
# 12273  3220079017  20150213T000000   432000.0         5       2.75
# 14682  7278100515  20140821T000000  1295000.0         2       2.50
# 15997  2320069260  20141027T000000   415000.0         3       2.00
# 16120  2574900080  20140513T000000  1550000.0         5       3.25
# 17312  3585901025  20140613T000000  1735000.0         3       2.50
# 18991  7856400300  20140702T000000  1411600.0         2       2.50
# 18992  7856400300  20150322T000000  1505000.0         2       2.50
#
# ...

# %%
df2['price'].describe()
# Out:
# count    1.300000e+01
# mean     1.353912e+06
# std      7.608267e+05
# min      4.150000e+05
# 25%      5.500000e+05
# 50%      1.505000e+06
# 75%      1.575000e+06
# max      3.000000e+06
# Name: price, dtype: float64

# %%
df3 = df[(df['sqft_basement']==0) & (df['floors']==2) & (df['price']<=150000)]
df3
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 11255  1843200350  20140722T000000  150000.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 11255         1360      1934     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# ...

# %%
df3['condition'].describe()
# Out:
# count    7.0
# mean     3.0
# std      1.0
# min      1.0
# 25%      3.0
# 50%      3.0
# 75%      3.5
# max      4.0
# Name: condition, dtype: float64

# %%
df3['condition'].mean()
# Out:
# 3.0
